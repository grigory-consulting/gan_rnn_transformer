# %%
# %pip install pandas scikit-learn # scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dokumentenklassifikation

doc1 = "I love programming in Python. Python is great for data science."
doc2 = "The weather today is sunny and warm. Perfect for a walk in the park."
doc3 = "Python and R are popular languages for data analysis."
doc4 = "It's going to rain tomorrow. Don't forget your umbrella!"


documents = [doc1, doc2, doc3, doc4]
